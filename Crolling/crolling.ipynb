# %%
import pandas as pd
from pathlib import Path

# --- 경로 설정 ---
ROOT_DIR = Path.cwd().parent 
DATA_DIR = ROOT_DIR / "BIgcontest_Data"
CROLLING_DIR = ROOT_DIR / "Crolling"
EDA_DIR = ROOT_DIR / "EDA"
MODEL_DIR = ROOT_DIR / "Model"

# %%
import pandas as pd

# CSV 파일을 읽어옵니다.
# 파일이 스크립트와 같은 폴더에 있는지 확인해주세요.
# 한글이 포함된 파일이므로 'cp949' 인코딩을 사용합니다.
try:
    df = pd.read_csv(DATA_DIR/'서울시 성동구 일반음식점 인허가 정보.csv', encoding='cp949')

    # '영업상태명' 컬럼의 값이 '폐업'이 아닌 데이터만 남깁니다.
    df_open = df[df['영업상태명'] != '폐업'].copy()

    # 필터링된 데이터를 새로운 CSV 파일로 저장합니다.
    # 엑셀에서 한글이 깨지지 않도록 'utf-8-sig' 인코딩을 사용합니다.
    output_file_path = DATA_DIR/'서울시_성동구_일반음식점_영업중.csv'
    df_open.to_csv(output_file_path, index=False, encoding='utf-8-sig')

    print(f"작업 완료! '{output_file_path}' 파일로 저장되었습니다.")
    print(f"처리 전 데이터 수: {len(df)}")
    print(f"처리 후 (영업중) 데이터 수: {len(df_open)}")

except FileNotFoundError:
    print("오류: '서울시 성동구 일반음식점 인허가 정보.csv' 파일을 찾을 수 없습니다.")
    print("파일이 올바른 경로에 있는지 확인해주세요.")
except Exception as e:
    print(f"오류가 발생했습니다: {e}")
# Out:
# 작업 완료! 'c:\Users\hyunj\Bigcontest\BIgcontest_Data\서울시_성동구_일반음식점_영업중.csv' 파일로 저장되었습니다.
# 처리 전 데이터 수: 14785
# 처리 후 (영업중) 데이터 수: 3982

# %%
def map_restaurants(open_restaurants_file, big_data_file, output_file):
    """
    두 데이터셋에서 마스킹된 이름과 실제 이름을 비교하여 가맹점을 매핑하고 결과를 저장합니다.

    Args:
        open_restaurants_file (str): 영업 중인 음식점 정보 CSV 파일 경로
        big_data_file (str): 마스킹된 가맹점 이름이 포함된 빅데이터 CSV 파일 경로
        output_file (str): 결과를 저장할 CSV 파일 경로
    """
    try:
        # 데이터 파일들을 읽어옵니다.
        # '서울시_성동구_일반음식점_영업중.csv'는 utf-8-sig로 저장했으므로 그대로 읽습니다.
        restaurants_open = pd.read_csv(open_restaurants_file, encoding='utf-8-sig')
        # big_data_file을 'cp949' 인코딩으로 읽도록 수정합니다.
        big_data = pd.read_csv(big_data_file, encoding='cp949')

        # '사업장명'과 'MCT_NM' 컬럼이 비어있는 경우를 대비하고, 문자열로 타입을 통일합니다.
        restaurants_open['사업장명'] = restaurants_open['사업장명'].astype(str).fillna('')
        big_data['MCT_NM'] = big_data['MCT_NM'].astype(str).fillna('')

        # 매핑된 결과를 저장할 리스트를 생성합니다.
        mapped_data = []

        # 빅데이터 파일의 각 가맹점을 하나씩 확인합니다.
        for index, row in big_data.iterrows():
            masked_name = row['MCT_NM']

            # 요청하신 조건: 이름이 4글자이고 '**'로 끝나는 경우 (예: "가나**")
            if len(masked_name) == 4 and masked_name.endswith('**'):
                prefix = masked_name[:2] # 앞 두 글자를 추출합니다. (예: "가나")

                # 영업 중인 음식점 목록에서 조건에 맞는 후보를 찾습니다.
                potential_matches = restaurants_open[
                    (restaurants_open['사업장명'].str.len() == 4) &
                    (restaurants_open['사업장명'].str.startswith(prefix))
                ]

                # 조건에 맞는 음식점을 찾았다면,
                if not potential_matches.empty:
                    matched_row = potential_matches.iloc[0]
                    mapped_data.append({
                        'ENCODED_MCT': row['ENCODED_MCT'],
                        '사업장명': matched_row['사업장명'],
                        '도로명주소': matched_row['도로명주소']
                    })

        # 매핑된 결과 리스트를 데이터프레임으로 변환합니다.
        mapped_df = pd.DataFrame(mapped_data)

        # 완성된 데이터프레임을 CSV 파일로 저장합니다.
        mapped_df.to_csv(output_file, index=False, encoding='utf-8-sig')

        print(f"총 {len(mapped_df)}개의 가맹점을 매핑하여 '{output_file}' 파일로 저장했습니다.")
        print("\n매핑된 데이터 샘플:")
        print(mapped_df.head())

    except FileNotFoundError as e:
        print(f"오류: {e.filename} 파일을 찾을 수 없습니다. 파일 경로를 확인해주세요.")
    except KeyError as e:
        print(f"오류: 파일에서 {e} 컬럼을 찾을 수 없습니다. 컬럼명을 확인해주세요.")
    except Exception as e:
        print(f"예상치 못한 오류가 발생했습니다: {e}")

# --- 아래 파일 이름들을 실제 파일 경로에 맞게 수정하여 사용하세요 ---
open_restaurants_filename = DATA_DIR/'서울시_성동구_일반음식점_영업중.csv'
big_data_filename = DATA_DIR/'big_data_set1_f.csv'
output_filename = DATA_DIR/'mapped_restaurants.csv'

# 매핑 함수를 실행합니다.
map_restaurants(open_restaurants_filename, big_data_filename, output_filename)

# %%
import pandas as pd
import requests
import os
import time
from dotenv import load_dotenv

def find_restaurant_name_kakao(address, masked_name, api_key):
    """
    카카오맵 '음식점' 카테고리 내에서 마스킹된 이름과 글자 수가 일치하는 가게를 찾습니다.
    """
    url = "https://dapi.kakao.com/v2/local/search/keyword.json"
    headers = {"Authorization": f"KakaoAK {api_key}"}
    
    prefix = masked_name.split('*')[0]
    original_len = len(masked_name)
    
    query = f"{address} {prefix}"
    params = {"query": query, "category_group_code": "FD6", "size": 15}
    
    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()
        
        if data['documents']:
            for doc in data['documents']:
                place_name = doc['place_name']
                if place_name.startswith(prefix) and len(place_name) == original_len:
                    return place_name
        
        return "Not Found"
        
    except requests.exceptions.RequestException as e:
        print(f"API 요청 오류: {e}")
        return "API Error"
    except Exception as e:
        print(f"처리 중 오류: {e}")
        return "Processing Error"

# --- 메인 코드 실행 부분 ---

# 1. .env 파일에서 환경 변수(API 키) 불러오기
load_dotenv()
kakao_api_key = os.getenv("KAKAO_API_KEY")

if not kakao_api_key:
    print("오류: .env 파일에서 KAKAO_API_KEY를 찾을 수 없거나 파일이 존재하지 않습니다.")
    print("스크립트와 같은 폴더에 .env 파일이 있는지, 파일 내용이 올바른지 확인해주세요.")
else:
    # 2. 데이터 파일 불러오기
    big_data_filename = DATA_DIR/'big_data_set1_f.csv'
    output_filename = DATA_DIR/'big_data_with_kakao_names_v3.csv'

    try:
        big_data = pd.read_csv(big_data_filename, encoding='cp949')
        
        # 테스트를 위해 상위 20개 데이터만 사용 (전체는 .head(20) 제거)
        df_sample = big_data.copy()
        
        df_sample['FOUND_MCT_NM'] = ''

        print("개선된 로직(.env 사용)으로 가맹점 실제 이름을 찾는 중입니다...")
        
        # 3. 각 행에 대해 개선된 함수 실행
        for index, row in df_sample.iterrows():
            if pd.isna(row['MCT_BSE_AR']) or pd.isna(row['MCT_NM']):
                continue
            
            found_name = find_restaurant_name_kakao(row['MCT_BSE_AR'], row['MCT_NM'], kakao_api_key)
            df_sample.loc[index, 'FOUND_MCT_NM'] = found_name
            
            print(f"  - 주소: {row['MCT_BSE_AR']}, 이름: {row['MCT_NM']} -> 찾은 이름: {found_name}")
            time.sleep(0.1)

        # 4. 결과 저장
        df_sample.to_csv(output_filename, index=False, encoding='utf-8-sig')

        print(f"\n작업 완료! 결과가 '{output_filename}' 파일로 저장되었습니다.")
        print("\n결과 미리보기:")
        print(df_sample[['MCT_BSE_AR', 'MCT_NM', 'FOUND_MCT_NM']].head())

    except FileNotFoundError:
        print(f"오류: '{big_data_filename}' 파일을 찾을 수 없습니다.")
    except KeyError as e:
        # 'MCT_BSE_AR' 컬럼명을 잘못 입력했을 때를 대비한 오류 처리
        print(f"오류: DataFrame에서 '{e}' 컬럼을 찾을 수 없습니다. CSV 파일의 컬럼명을 확인해주세요.")
    except Exception as e:
        print(f"파일 처리 중 오류가 발생했습니다: {e}")
# Out:
# 개선된 로직(.env 사용)으로 가맹점 실제 이름을 찾는 중입니다...
#   - 주소: 서울 성동구 마장동, 이름: 성우** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장동, 이름: 대보** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장동, 이름: 대용** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장동, 이름: 통일** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장동, 이름: 한울** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장동, 이름: 대광** -> 찾은 이름: 대광상회
#   - 주소: 서울 성동구 마장동, 이름: 미림** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장동, 이름: 호남* -> 찾은 이름: 호남집
#   - 주소: 서울 성동구 사근동, 이름: 고향*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 송정동, 이름: 북* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답동, 이름: 좋은** -> 찾은 이름: 좋은세상
#   - 주소: 서울 성동구 용답동, 이름: 별난** -> 찾은 이름: 별난만두
#   - 주소: 서울 성동구 행당동, 이름: 행당** -> 찾은 이름: 행당족발
#   - 주소: 서울 성동구 행당동, 이름: 이혜******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 홍익동, 이름: 정* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 홍익동, 이름: 조은** -> 찾은 이름: 조은식당
#   - 주소: 서울 성동구 행당1동, 이름: 왕십**** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  도선동, 이름: 광한****** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 멕시***** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 도미******** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 현대** -> 찾은 이름: 현대족발
#   - 주소: 서울  성동구  마장동, 이름: 청계** -> 찾은 이름: 청계분식
#   - 주소: 서울  성동구  마장동, 이름: 한양** -> 찾은 이름: 한양포차
#   - 주소: 서울  성동구  마장동, 이름: 한일** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 세화** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 대성** -> 찾은 이름: 대성식당
#   - 주소: 서울  성동구  마장동, 이름: 광* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 희망** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 한일** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 세계** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 파리********** -> 찾은 이름: 파리바게뜨 왕십리역사점
#   - 주소: 서울  성동구  마장동, 이름: 진* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 삼대** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 대구* -> 찾은 이름: 대구집
#   - 주소: 서울  성동구  마장동, 이름: 원조*** -> 찾은 이름: 원조용문집
#   - 주소: 서울  성동구  마장동, 이름: 훈희*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 몽실****** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 순대** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장동, 이름: 동원** -> 찾은 이름: 동원식당
#   - 주소: 서울  성동구  마장로, 이름: 마장***** -> 찾은 이름: 마장갈비 본점
#   - 주소: 서울  성동구  무학로, 이름: 와이*********** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  상원길, 이름: 맛드* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  상원길, 이름: 피자******** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  상원길, 이름: 담바* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  송정동, 이름: 델리** -> 찾은 이름: 델리키친
#   - 주소: 서울  성동구  송정동, 이름: 본토**** -> 찾은 이름: 본토고기구이
#   - 주소: 서울  성동구  용답동, 이름: 동부** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  용답동, 이름: 고향** -> 찾은 이름: 고향식당
#   - 주소: 서울  성동구  응봉동, 이름: 풀무********* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  응봉동, 이름: 단아** -> 찾은 이름: 단아떡방
#   - 주소: 서울  성동구  행당동, 이름: 영* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  행당동, 이름: 에스****** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  행당동, 이름: 종로** -> 찾은 이름: 종로떡집
#   - 주소: 서울  성동구  행당동, 이름: 만두** -> 찾은 이름: 만두전빵
#   - 주소: 서울  성동구  행당동, 이름: 코페* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  행당동, 이름: 아폴********* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  행당동, 이름: 무탁**** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  홍익동, 이름: 정은**** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  홍익동, 이름: 맛나** -> 찾은 이름: 맛나식당
#   - 주소: 서울 성동구 마조로 9, 이름: 설빙**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 무학로 8, 이름: 70****** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  상원6길, 이름: 오가****** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  옥수2동, 이름: 극동***** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  옥수2동, 이름: 전주******* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  옥수2동, 이름: 양지*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  옥수2동, 이름: 장군** -> 찾은 이름: 장군장어
#   - 주소: 서울  성동구  옥수2동, 이름: 돈까* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  행당1동, 이름: 돔카* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  행당1동, 이름: 한양*********** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  행당1동, 이름: 한양*** -> 찾은 이름: 한양양곱창
#   - 주소: 서울  성동구  행당2동, 이름: 김밥** -> 찾은 이름: 김밥마루
#   - 주소: 서울  성동구  행당2동, 이름: 대림**** -> 찾은 이름: 대림호프포차
#   - 주소: 서울 성동구 금호동2가, 이름: 닭한***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호동3가, 이름: 귀일** -> 찾은 이름: 귀일만두
#   - 주소: 서울 성동구 금호로 56, 이름: 해장*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 62, 이름: 교촌****** -> 찾은 이름: 교촌치킨 응봉점
#   - 주소: 서울 성동구 금호로 66, 이름: 광주** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 동일로 83, 이름: 와규** -> 찾은 이름: 와규오감
#   - 주소: 서울 성동구 동일로 83, 이름: 참나***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 11, 이름: 써브****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 17, 이름: 대* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 17, 이름: 돼지* -> 찾은 이름: 돼지꿈
#   - 주소: 서울 성동구 마조로 17, 이름: 장어** -> 찾은 이름: 장어구이
#   - 주소: 서울 성동구 마조로 17, 이름: 놀란* -> 찾은 이름: 놀란닭
#   - 주소: 서울 성동구 마조로 25, 이름: 토리******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 29, 이름: 성일*** -> 찾은 이름: 성일순대국
#   - 주소: 서울 성동구 마조로 31, 이름: 맘스******* -> 찾은 이름: 맘스터치 한양대점
#   - 주소: 서울 성동구 마조로 33, 이름: 한솥*********** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 33, 이름: 동방*** -> 찾은 이름: 동방양꼬치
#   - 주소: 서울 성동구 마조로 35, 이름: 크로******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 39, 이름: 스마* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 7., 이름: 철* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 매봉길 2., 이름: 인덕*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 매봉길 2., 이름: 파파***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 무학로 33, 이름: 왕십********** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 무학로 42, 이름: 벽산**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 상원6길 5, 이름: 춘천*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 상원8길 1, 이름: 가든*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 상원길 52, 이름: 둘둘*********** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 상원길 54, 이름: 이흥*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 상원길 60, 이름: 왕짜* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성수동2가, 이름: 맛닭****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성수동2가, 이름: 삼오*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성수동2가, 이름: 찐짜** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성수동2가, 이름: 20**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성수동2가, 이름: 빙아******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터3길 8, 이름: 뚱이*** -> 찾은 이름: 뚱이감자탕
#   - 주소: 서울 성동구 장터길 23, 이름: 롯데****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 25, 이름: 두레****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 30, 이름: 먹거**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 37, 이름: 온달*** -> 찾은 이름: 온달왕족발
#   - 주소: 서울 성동구 장터길 47, 이름: 백미* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 47, 이름: 진미** -> 찾은 이름: 진미곱창
#   - 주소: 서울 성동구 장터길 49, 이름: 은하* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로 38, 이름: 덕흥*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로 79, 이름: 비타*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  무수막길, 이름: 강정*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  무수막길, 이름: 미스*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  상원12길, 이름: 예* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 151, 이름: 포마*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 168, 이름: 사와** -> 찾은 이름: 사와분식
#   - 주소: 서울 성동구 금호로 17., 이름: 마테**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 17., 이름: 해* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 17., 이름: 유어*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 40., 이름: 금호************** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 45., 이름: 필라******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 56., 이름: 만족******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 66., 이름: 대중***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 84., 이름: 장미** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 86., 이름: 삼덕** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 난계로 32., 이름: 지코******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 난계로 35., 이름: 이디*********** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 난계로 97., 이름: 삼미** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 둘레5길 15, 이름: 지성** -> 찾은 이름: 지성식당
#   - 주소: 서울 성동구 뚝섬로 404, 이름: 풍년** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 뚝섬로 404, 이름: 중국* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 137, 이름: 퍼멘***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 192, 이름: 수원** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 199, 이름: 겨울** -> 찾은 이름: 겨울연가
#   - 주소: 서울 성동구 마장로 211, 이름: 소대** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 223, 이름: 김밥** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 227, 이름: 달리*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 232, 이름: 권가* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 283, 이름: 세계******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 296, 이름: 비어** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 321, 이름: 나* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 326, 이름: 들창* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 17., 이름: 레드** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 17., 이름: 금* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 17., 이름: 든든**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 17., 이름: 주물**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 17., 이름: 올레******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 17., 이름: 육지** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 17., 이름: 꼬지*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 17., 이름: 이모***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 17., 이름: 더구** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 17., 이름: 양대* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 21., 이름: 금* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 21., 이름: 쏘러* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 21., 이름: 빽다****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 25., 이름: 뉴스***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 
-> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 100., 이름: 한* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 100., 이름: 현준** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 102., 이름: 가츠** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 164., 이름: 청과**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 168., 이름: 먹태** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 40 ., 이름: 커스******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 47-1, 이름: 금수* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호산길 62, 이름: 해마****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호산길 71, 이름: 전주** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 동일로 143., 이름: 우마************ -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 동일로 143., 이름: 밥내* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 동일로 265., 이름: 싱싱*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 동호로 102., 이름: 더건*************** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 동호로 93 ., 이름: 비에*************** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 동호로 93 ., 이름: 파리******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 둘레11길 26, 이름: 우* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 둘레15길 14, 이름: 행복** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 둘레15길 16, 이름: 농우* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 뚝섬로 321., 이름: 국수*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 뚝섬로 337., 이름: 성수** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 뚝섬로 338., 이름: 뚝섬*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 뚝섬로 389., 이름: 한촌********* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 뚝섬로 392., 이름: 또래** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 뚝섬로 392., 이름: 규리****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 뚝섬로 426., 이름: 홍정* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 뚝섬로 447., 이름: 스* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 137., 이름: 웃긴**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 137., 이름: 낀부********** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 137., 이름: 고고*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 137., 이름: 서오*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 137., 이름: 본도******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 137., 이름: 안수* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 137., 이름: 고(******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 137., 이름: 컴포*********** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 137., 이름: 유림**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 137., 이름: 누들************ -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 137., 이름: 나마***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 185., 이름: 태평*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 223., 이름: 야미* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 228., 이름: 장충******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 228., 이름: 대게****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 231., 이름: 목포** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 244., 이름: 잼(****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 274., 이름: 우리****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 280., 이름: 지에************ -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 283., 이름: 김밥** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 283., 이름: 하은*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 284., 이름: 대성* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 285., 이름: 조개**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 299., 이름: 피자****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 327., 이름: 군산** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 328., 이름: 별바* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 15-2, 이름: 구이** -> 찾은 이름: 구이마을
#   - 주소: 서울 성동구 마조로 17 ., 이름: 우리****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로 35 ., 이름: 버거* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로3길 6, 이름: 알촌***** -> 찾은 이름: 알촌 한양대점
#   - 주소: 서울 성동구 마조로3길 8, 이름: 이모**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로5길 3, 이름: 황소** -> 찾은 이름: 황소곱창
#   - 주소: 서울 성동구 마조로5길 5, 이름: 청년************* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로5길 7, 이름: 김종****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마조로7길 6, 이름: 싱싱***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 무수막길 3., 이름: 참나****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 무수막길 94, 이름: 착한****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 무수막길 95, 이름: 우리** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 무학로 10-1, 이름: 케이**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 무학로6길 5, 이름: 고향** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 무학봉길 83, 이름: 여수**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 무학봉길 88, 이름: 토상** -> 찾은 이름: 토상막회
#   - 주소: 서울 성동구 사근동8길 8, 이름: 다시*** -> 찾은 이름: 다시올치킨
#   - 주소: 서울 성동구 사근동길 4., 이름: 피자******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 사근동길 4., 이름: 우리** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 사근동길 55, 이름: 사* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 사근동길 58, 이름: 우리** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 사근동길 6., 이름: 투고*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 살곶이길 40, 이름: 고깃**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 상원12길 12, 이름: 강북** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 상원1길 13., 이름: 스테************ -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 상원1길 26., 이름: 대성** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 상원1길 33., 이름: 야끼**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 상원6길 6-1, 이름: 호타* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성덕정길 25, 이름: 영구******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성덕정길 37, 이름: 얼큰**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성덕정길 46, 이름: 백두** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성덕정길 75, 이름: 옛날***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성덕정길 78, 이름: 피자**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성덕정길 90, 이름: 싱싱** -> 찾은 이름: 싱싱횟집
#   - 주소: 서울 성동구 성덕정길 91, 이름: 떡마* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성덕정길 99, 이름: 신화*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성수일로 59, 이름: 장흥** -> 찾은 이름: 장흥식당
#   - 주소: 서울 성동구 아차산로 87, 이름: 삼천* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 아차산로 87, 이름: 다도** -> 찾은 이름: 다도식당
#   - 주소: 서울 성동구 아차산로 93, 이름: 펀비** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 아차산로 96, 이름: 행* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 연무장길 17, 이름: 외가* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 78, 이름: 승리* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답19길 5., 이름: 조개**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답19길 9., 이름: 애솔***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답29길 13, 이름: 한길** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답동 14-2, 이름: 동수****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답동 47-1, 이름: 소문******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 25-1, 이름: 명가**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 38-1, 이름: 박재***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 39-1, 이름: 경북** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 43-3, 이름: 짱구***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말길 17, 이름: 옥수***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당동 17-7, 이름: 카페******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로 109., 이름: 행당** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로 129., 이름: 폰아************* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로 129., 이름: 곽선**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로 129., 이름: 봉구************ -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로 87 ., 이름: 낙원** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로 89 ., 이름: 이영****** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마조로  17, 이름: 원조**** -> 찾은 이름: 원조사철냉면
#   - 주소: 서울  성동구  마조로  55, 이름: 신선*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  매봉길  12, 이름: 이디*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  상원길  49, 이름: 뚝섬** -> 찾은 이름: 뚝섬돈가
#   - 주소: 서울  성동구  상원길  64, 이름: 한우*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수1가1동, 이름: 한* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수1가1동, 이름: 비어** -> 찾은 이름: 비어만땅
#   - 주소: 서울  성동구  성수1가1동, 이름: 초원** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수1가1동, 이름: 장원** -> 찾은 이름: 장원식당
#   - 주소: 서울  성동구  성수1가2동, 이름: 청록*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수1가2동, 이름: 땅끝****** -> 찾은 이름: 땅끝마을회뜨는집
#   - 주소: 서울  성동구  성수1가2동, 이름: 죽변* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수2가1동, 이름: 김밥** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수2가1동, 이름: 장미*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수2가1동, 이름: 뚝섬*** -> 찾은 이름: 뚝섬해물탕
#   - 주소: 서울  성동구  성수2가1동, 이름: 파리*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수2가1동, 이름: 머니** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수2가1동, 이름: 명원*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수2가3동, 이름: 파리********* -> 찾은 이름: 파리바게뜨 서울숲역점
#   - 주소: 서울  성동구  성수2가3동, 이름: 동맛****** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수2가3동, 이름: 옛골*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  장터5길  1, 이름: 금호** -> 찾은 이름: 금호족발
#   - 주소: 서울  성동구  하왕십리동, 이름: 엘림**** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  행당로  98, 이름: 더리* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 263, 이름: 거창** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 287, 이름: 왕십****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 344, 이름: 서울** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 346, 이름: 미성**** -> 찾은 이름: 미성숯불갈비
#   - 주소: 서울 성동구 광나루로 287, 이름: 싸리* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 광나루로 289, 이름: 닭한***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 광나루로 290, 이름: 진지**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 광나루로 290, 이름: 완산*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호로 127 ., 이름: 목포** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구
-> 찾은 이름: Not Found
#   - 주소: 서울 성동구 연무장5길 6., 이름: 문츠*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 연무장길 39., 이름: 에이*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 연무장길 77., 이름: 세계********* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 연무장길 84., 이름: 플라******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 102, 이름: 베스**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 104, 이름: 에이******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 275, 이름: 짱호*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 294, 이름: 전주* -> 찾은 이름: 전주집
#   - 주소: 서울 성동구 왕십리로 330, 이름: 은좌** -> 찾은 이름: 은좌식당
#   - 주소: 서울 성동구 왕십리로 355, 이름: 시골**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 357, 이름: 라빠***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 58., 이름: 팜티***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 78., 이름: 베트********* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 88., 이름: 블레* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 92., 이름: 파리******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답19길 13., 이름: 술사* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답19길 15., 이름: 북촌****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답25길 15., 이름: 제* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답29길 11., 이름: 한가****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답29길 28., 이름: 럼프** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터1가길 51, 이름: 옥수**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터5길 3-1., 이름: 초가* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터5길 4-1., 이름: 중화***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 13-1., 이름: 만리** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 22-1., 이름: 맛닭****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 38-1., 이름: 사또** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 40-4., 이름: 지오**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 장터길 44-1., 이름: 수구* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 천호대로 276, 이름: 일인** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 천호대로 294, 이름: 또바*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 천호대로 296, 이름: 장어** -> 찾은 이름: 장어시대
#   - 주소: 서울 성동구 천호대로 312, 이름: 파리******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말1길 8., 이름: 콩물***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말3길 14, 이름: 달* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말5길 7., 이름: 프로**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말길 40., 이름: 구* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당동 19-54, 이름: 소나*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로 108-1, 이름: 국수******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로17길 5, 이름: 명랑***** -> 찾은 이름: 명랑즉석떡볶이
#   - 주소: 서울 성동구 행당로17길 5, 이름: 우리* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로6길 2., 이름: 명품******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로8길 5., 이름: 신사******* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  광나루로6길, 이름: 깡통* -> 찾은 이름: 깡통집
#   - 주소: 서울  성동구  마장로  305, 이름: 아씨*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장로  305, 이름: 남원*** -> 찾은 이름: 남원추어탕
#   - 주소: 서울  성동구  사근동길  2, 이름: 카페*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수이로7길, 이름: 원할*********** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  하왕십리1동, 이름: 동순* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  하왕십리2동, 이름: 멕시*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  하왕십리2동, 이름: 기분**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 177., 이름: 치킨*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 202., 이름: 메가*********** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 253., 이름: 김정******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 269., 이름: 전주******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 281., 이름: 왕십*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 281., 이름: 동막* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 293., 이름: 월드******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 293., 이름: 양* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 293., 이름: 곱창**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 293., 이름: 진국*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 297., 이름: 왕십********* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 323., 이름: 통통*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 331., 이름: 마장********* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 340., 이름: 운정** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 344., 이름: 화신**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 345., 이름: 둘* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 345., 이름: 봉구******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 349., 이름: 한우**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 광나루로 156., 이름: 참새**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 광나루로 307., 이름: 문화**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 광나루로 319., 이름: 불백*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 광나루로 323., 이름: 왕호*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 광나루로9길 3, 이름: 골목** -> 찾은 이름: 골목식당
#   - 주소: 서울 성동구 금호동3가 207, 이름: 바람***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구
-> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 329., 이름: 재래** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 330., 이름: 본죽***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 336., 이름: 경희**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 340., 이름: 백남******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 357., 이름: 피자******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 362., 이름: 마시*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 410., 이름: 카페**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 410., 이름: 희낭** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 410., 이름: 희유**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 410., 이름: 신의****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 410., 이름: 카츠* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 410., 이름: 헬키******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로4길 1, 이름: 장수***** -> 찾은 이름: 장수오리생삼겹
#   - 주소: 서울 성동구 용답15길 10-1, 이름: 이천*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답19길 16-1, 이름: 후루*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답25길 6-11, 이름: 금성** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답25라길 23, 이름: 부흥** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답25라길 23, 이름: 행복********** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답중앙길 12, 이름: 대광** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답중앙길 67, 이름: 충북** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답중앙길 72, 이름: 오늘** -> 찾은 이름: 오늘회식
#   - 주소: 서울 성동구 천호대로 440., 이름: 와이************ -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 청계천로 426., 이름: 여러*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 청계천로 494., 이름: Mr***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말1길 13., 이름: 제주**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말1길 16., 이름: 오늘****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말3길 10., 이름: 오솜** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말3길 29., 이름: 더 ****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말3길 31., 이름: 개미** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말5길 11., 이름: 둘둘** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말5길 19., 이름: 빈플** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 한림말길 31 ., 이름: DA******** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로 125-3., 이름: 코스* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로 127-1., 이름: 광동******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로17길 11, 이름: 꼬랑** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로17길 13, 이름: 왕십***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로17길 16, 이름: 먹거**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로17길 18, 이름: 행당**** -> 찾은 이름: 행당닭한마리
#   - 주소: 서울 성동구 행당로17길 24, 이름: 푸줏***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로17길 7., 이름: 왕십***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로8길 13., 이름: 왕손*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 행당로8길 5-1, 이름: 늘푸**** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  금호로  82-1, 이름: 함흥*** -> 찾은 이름: 함흥순대국
#   - 주소: 서울  성동구  금호산길  58, 이름: 노* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  독서당로40길, 이름: 신의***** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  마장로35다길, 이름: 대용** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  상원10길  16, 이름: 김종*** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  성수이로  54, 이름: 짬뽕** -> 찾은 이름: 짬뽕타운
#   - 주소: 서울  성동구  아차산로  87, 이름: 을지****** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  연무장길  45, 이름: 혜성** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  왕십리로  38, 이름: 채선* -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  장터길  22-1, 이름: 엄마** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  한림말3길  2, 이름: 파리*********** -> 찾은 이름: Not Found
#   - 주소: 서울  성동구  한림말3길  8, 이름: 더코*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로 337-1, 이름: 조은** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로2길 14, 이름: 고고** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로2길 4., 이름: 축산*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로6길 40, 이름: 라인****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로8길 18, 이름: 부자** -> 찾은 이름: 부자식당
#   - 주소: 서울 성동구 광나루로 130 ., 이름: 포레****************** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 광나루로11길 3, 이름: 석천******* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호산2길 30-1, 이름: 희* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호산길 49-1., 이름: 먹깨**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 금호산길 53-1., 이름: 채원****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 독서당로 296-8, 이름: 동원* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 독서당로 303-6, 이름: 왕칼** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 독서당로 307-1, 이름: 지연**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 뚝섬로 385-32., 이름: 육* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 뚝섬로 385-32., 이름: 명태* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 228-18., 이름: 체* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로 228-24., 이름: 다* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로23길 4 ., 이름: 대촌* -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로26길 16., 이름: 왕십**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로27길 11., 이름: 용두** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로29길 40., 이름: 궁중** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로31가길 6, 이름: 임하** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로31길 34., 이름: 경지** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로31길 40., 이름: 대광** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로31길 40., 이름: 청운** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로31길 44., 이름: 삼보** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로31길 48., 이름: 순창** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로35길 66., 이름: 대한** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로35길 68., 이름: 마장****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로35길 70., 이름: 몽실** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로35나길 3, 이름: 한국** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로35나길 4, 이름: 현대** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로35다길 9, 이름: 삼형*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로35다길 9, 이름: 대용***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로35다길 9, 이름: 대성** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로35다길 9, 이름: 영양** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로35다길 9, 이름: 누리** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로37길 40., 이름: 영남**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로37길 43., 이름: 창민** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로37길 53., 이름: 한일*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로37길 53., 이름: 마장**** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로37길 59., 이름: 한우** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로37길 59., 이름: 한우************ -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 마장로39길 14., 이름: 동일** -> 찾은 이름: Not Found
# ...
#   - 주소: 서울특별시 성동구 마장로35길 112-4, 이름: 한나******* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 마장로35나길 3-7, 이름: 수민** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 마장로35다길 4-9, 이름: 하경** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성덕정17길 4, 이름: 럭럭** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수이로12길 8-1, 이름: 월스******* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수이로3길 10-1, 이름: 성수****************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수이로7길 41-1, 이름: 옹근* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로10가길 4, 이름: 올드** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로11길 6-1, 이름: 소바* -> 찾은 이름: 소바짐
#   - 주소: 서울특별시 성동구 성수일로3길 4-13, 이름: 아도******* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로3길 4-13, 이름: 핀* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로3길 5-12, 이름: 바* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로3길 5-12, 이름: 퍼멘****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로4가길 10, 이름: 더블********* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로8길 39-1, 이름: 이트**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로8길 40-1, 이름: 무근* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 아차산로1가길 10, 이름: 플로********* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 아차산로1가길 11, 이름: 아워** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 아차산로1길 11-1, 이름: 피자* -> 찾은 이름: 피자인
#   - 주소: 서울특별시 성동구 아차산로7가길 21, 이름: 귀농** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 아차산로7길 14-1, 이름: 모* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 아차산로7길 17-1, 이름: 삼* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 아차산로7길 17-1, 이름: 착한** -> 찾은 이름: 착한짜장
#   - 주소: 서울특별시 성동구 아차산로7길 42-1, 이름: 온유***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 아차산로7나길 18, 이름: 피자***** -> 찾은 이름: 피자헛 성수점
#   - 주소: 서울특별시 성동구 아차산로7나길 18, 이름: 밥플*********** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 아차산로7나길 18, 이름: 개성** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 아차산로9길 30-9, 이름: 오씨****************************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 연무장5가길 22-1, 이름: 브루****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로 지하300, 이름: 제이*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로 지하300, 이름: 어묵********** -> 찾은 이름: 어묵애꼬치다 왕십리역점
#   - 주소: 서울특별시 성동구 왕십리로10길 5-1, 이름: 간다**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로10길 5-6, 이름: 세븐****************************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로10길 5-9, 이름: 브샤***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로10길 9-9, 이름: 어린* -> 찾은 이름: 어린달
#   - 주소: 서울특별시 성동구 왕십리로10길 9-9, 이름: 제* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로21가길 1, 이름: 려기**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로21가길 3, 이름: 별* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로21나길 5, 이름: 더블* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로21나길 9, 이름: 꼬팡************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로24길 1-1, 이름: 시크*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로24길 7-1, 이름: 왕십***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로24길 7-2, 이름: 동네** -> 찾은 이름: 동네오빠
#   - 주소: 서울특별시 성동구 왕십리로24나길 4, 이름: 키친*** -> 찾은 이름: 키친키요라
#   - 주소: 서울특별시 성동구 왕십리로24나길 8, 이름: 숙성** -> 찾은 이름: 숙성회심
#   - 주소: 서울특별시 성동구 왕십리로24나길 8, 이름: 일품***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로26길 7-2, 이름: 카츠*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로30길 2-1, 이름: 보리** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 10-1, 이름: 멘야****** -> 찾은 이름: 멘야코노하 성수
#   - 주소: 서울특별시 성동구 왕십리로4길 10-9, 이름: 밤토* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 13-1, 이름: 유메** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 13-1, 이름: 춘배** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 13-1, 이름: 다* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 13-1, 이름: 신* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 13-1, 이름: 성수* -> 찾은 이름: 성수라
#   - 주소: 서울특별시 성동구 왕십리로4길 19-1, 이름: 또보****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 19-1, 이름: 이태***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 22-1, 이름: 성수** -> 찾은 이름: 성수대파
#   - 주소: 서울특별시 성동구 왕십리로4길 23-1, 이름: 홍화* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 24-3, 이름: 면화**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 24-7, 이름: 비도******* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 24-7, 이름: 현 **** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 24-8, 이름: 제이**** -> 찾은 이름: 제이앤제이펍
#   - 주소: 서울특별시 성동구 왕십리로4길 26-7, 이름: 아카***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 26-7, 이름: 카타*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 28-2, 이름: 넘버*** -> 찾은 이름: 넘버파이브
#   - 주소: 서울특별시 성동구 왕십리로4길 28-2, 이름: 양복* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 28-2, 이름: 로우***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 28-8, 이름: 다이******** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 28-8, 이름: 감성** -> 찾은 이름: 감성요리
#   - 주소: 서울특별시 성동구 왕십리로5길 12-1, 이름: 성수**** -> 찾은 이름: 성수스타우트
#   - 주소: 서울특별시 성동구 왕십리로5길 12-2, 이름: 수원**** -> 찾은 이름: 수원원조갈비
#   - 주소: 서울특별시 성동구 왕십리로5길 12-3, 이름: 뚝섬**** -> 찾은 이름: 뚝섬숯불갈비
#   - 주소: 서울특별시 성동구 왕십리로5길 9-10, 이름: 버섯* -> 찾은 이름: 버섯집
#   - 주소: 서울특별시 성동구 왕십리로5길 9-16, 이름: 화포* -> 찾은 이름: 화포엠
#   - 주소: 서울특별시 성동구 왕십리로5길 9-16, 이름: 소녀********** -> 찾은 이름: 소녀방앗간 서울숲시작점
#   - 주소: 서울특별시 성동구 왕십리로5길 9-20, 이름: 뉴앳* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로5길 9-20, 이름: Se************ -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로5길 9-20, 이름: 핫쵸**** -> 찾은 이름: 핫쵸 성수점
#   - 주소: 서울특별시 성동구 왕십리로8길 18-1, 이름: 뱅인** -> 찾은 이름: 뱅인타코
#   - 주소: 서울특별시 성동구 왕십리로8길 18-1, 이름: 모피* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로8길 19-4, 이름: 뚝섬** -> 찾은 이름: 뚝섬포구
#   - 주소: 서울특별시 성동구 왕십리로8길 19-4, 이름: 마하******* -> 찾은 이름: 마하차이 서울숲점
#   - 주소: 서울특별시 성동구 왕십리로8길 19-6, 이름: 하우*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로8길 19-6, 이름: 경주** -> 찾은 이름: 경주이씨
#   - 주소: 서울특별시 성동구 왕십리로8길 21-1, 이름: 카페************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로8길 21-1, 이름: 채마**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 용답중앙13길 6-1, 이름: 교촌****** -> 찾은 이름: 교촌치킨 용답점
#   - 주소: 서울특별시 성동구 용답중앙13길 6-3, 이름: 죽토********* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 용답중앙13길 7-1, 이름: 건영** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 용답중앙15길 7-1, 이름: 가장*********** -> 찾은 이름: 가장맛있는족발 답십리역점
#   - 주소: 서울특별시 성동구 용답중앙15길 8-1, 이름: 탑* -> 찾은 이름: 탑바
#   - 주소: 서울특별시 성동구 자동차시장1길 30, 이름: 이도** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 30, 이름: 고* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 39, 이름: 일카* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 39, 이름: 의정***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 41, 이름: 한컵** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 카페** -> 찾은 이름: 카페와바
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 코롱** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 다* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 밀물** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 남도** -> 찾은 이름: 남도정식
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 전라*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 영광** -> 찾은 이름: 영광식당
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 삼천*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 광주** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 장평** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 이일****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 시골****** -> 찾은 이름: 시골순대 2호점
#   - 주소: 서울특별시 성동구 자동차시장1길 70, 이름: 서울** -> 찾은 이름: 서울식당
#   - 주소: 서울특별시 성동구 자동차시장1길 85, 이름: 그레****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 자동차시장1길 85, 이름: 그레***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 천호대로 지하300, 이름: 어묵** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10다길 1, 이름: 가나** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 고산자로24길 11-1, 이름: 경원** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 고산자로24길 11-1, 이름: 구공** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 고산자로24길 12-1, 이름: 내일*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 고산자로24길 14-2, 이름: 보경** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 고산자로24길 14-7, 이름: 소지**** -> 찾은 이름: 소지신찰순대
#   - 주소: 서울특별시 성동구 고산자로24길 15-1, 이름: 영화** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 고산자로24길 16-2, 이름: 풍원** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 광나루로11길 13-1, 이름: 구구** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 광나루로11길 17-1, 이름: 묘* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 광나루로11길 17-1, 이름: 자매**** -> 찾은 이름: 자매코다리찜
#   - 주소: 서울특별시 성동구 광나루로11길 22-1, 이름: 부산****** -> 찾은 이름: 부산돼지국밥보쌈
#   - 주소: 서울특별시 성동구 광나루로11길 52-1, 이름: 리커****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 금호산길 60-1, 이름: 삼형******* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 독서당로39길 43-1, 이름: 오렌******** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 독서당로39길 43-1, 이름: 소림****** -> 찾은 이름: 소림마라 성동점
#   - 주소: 서울특별시 성동구 독서당로39길 43-1, 이름: 연스*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 독서당로40길 25-1, 이름: 부부***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 독서당로46가길 28, 이름: 더빌** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 독서당로46길 38-1, 이름: 라파** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 독서당로47길 12-1, 이름: 곽쓰* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 독서당로51길 22-1, 이름: 카운*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 독서당로51길 29-1, 이름: 오부** -> 찾은 이름: 오부이용
#   - 주소: 서울특별시 성동구 독서당로51길 29-1, 이름: 오부** -> 찾은 이름: 오부이용
#   - 주소: 서울특별시 성동구 독서당로51길 34-1, 이름: 37****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 독서당로59나길 36, 이름: 정성** -> 찾은 이름: 정성식당
#   - 주소: 서울특별시 성동구 독서당로59다길 21, 이름: 오뚜**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 독서당로59다길 34, 이름: 진하** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 독서당로60가길 20, 이름: 이레** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 뚝섬로15길 31, 이름: 매* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 마장로35나길 3-22, 이름: 거승** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 마장로35나길 3-29, 이름: 신안** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 마장로35나길 3-33, 이름: 비앙********* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 마장로35나길 3-60, 이름: 남도** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 마장로35나길 3-60, 이름: 정육** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 살곶이2가길 27-19, 이름: 파로* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로12길 18-1, 이름: 예셰************* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로12길 19-1, 이름: 카페*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로1길 12-12, 이름: 20**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로4길 35-11, 이름: 커피******** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 아차산로13길 23-1, 이름: 제일*** -> 찾은 이름: 제일순대국
#   - 주소: 서울특별시 성동구 왕십리로10길 10-1, 이름: 우불** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로10길 18-1, 이름: 미디*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로10길 18-1, 이름: 토리** -> 찾은 이름: 토리무라
#   - 주소: 서울특별시 성동구 왕십리로10길 20-1, 이름: 아끄************* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로10길 9-14, 이름: 갓잇************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로10길 9-31, 이름: 스트***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로10길 9-31, 이름: 스트********* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로14길 12-1, 이름: 온센******* -> 찾은 이름: 온센 서울성동구점
#   - 주소: 서울특별시 성동구 왕십리로14길 19-2, 이름: 칠* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로14길 30-1, 이름: 구* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로14길 30-1, 이름: 파이******* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로14길 32-3, 이름: 홍천** -> 찾은 이름: 홍천숯닭
#   - 주소: 서울특별시 성동구 왕십리로16가길 10, 이름: 리커******* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로16길 13-1, 이름: 아뜰*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로16길 15-1, 이름: 젤코********************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로21길 10-1, 이름: 반찬** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로21길 10-1, 이름: 알맹******* -> 찾은 이름: 알맹치킨 왕십리점
#   - 주소: 서울특별시 성동구 왕십리로21길 39-1, 이름: 오블************* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로21길 39-1, 이름: 호남** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로21길 45-1, 이름: 연디** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로21다길 39, 이름: 수제****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로22길 10-1, 이름: 능한** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로24길 10-2, 이름: 고깃**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로24길 27-1, 이름: 후라************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로24길 27-1, 이름: 후라************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로24길 39-1, 이름: 황토** -> 찾은 이름: 황토족발
#   - 주소: 서울특별시 성동구 왕십리로24나길 10, 이름: 중화***** -> 찾은 이름: 중화반점 여의
#   - 주소: 서울특별시 성동구 왕십리로24나길 14, 이름: 류가*** -> 찾은 이름: 류가양꼬치
#   - 주소: 서울특별시 성동구 왕십리로24나길 20, 이름: 춘리******** -> 찾은 이름: 춘리마라탕 왕십리점
#   - 주소: 서울특별시 성동구 왕십리로31나길 21, 이름: 프레******** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로31나길 21, 이름: 서울** -> 찾은 이름: 서울식당
#   - 주소: 서울특별시 성동구 왕십리로4가길 2-9, 이름: 바버****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 10-12, 이름: 칼리***************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 10-12, 이름: 제비* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 10-12, 이름: 서울** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 24-19, 이름: 파머******** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 26-14, 이름: 성수** -> 찾은 이름: 성수온실
#   - 주소: 서울특별시 성동구 왕십리로4길 26-18, 이름: 식당* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 26-18, 이름: 엘* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 26-18, 이름: 스윗*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로4길 26-20, 이름: 소바** -> 찾은 이름: 소바마에
#   - 주소: 서울특별시 성동구 왕십리로4길 26-22, 이름: 맥문* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 용답중앙11길 16-1, 이름: 소담** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 용답중앙11길 18-1, 이름: 왕갈**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 용답중앙13길 14-1, 이름: 푸짐***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 용답중앙13길 16-1, 이름: 황우** -> 찾은 이름: 황우식당
#   - 주소: 서울특별시 성동구 용답중앙15길 15-2, 이름: 심봉****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 용답중앙23길 16-2, 이름: 모찌***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 장터길 21-1 ., 이름: 고기*********** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10가길 38, 이름: 고박******* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10나길 24, 이름: 고기** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10나길 33, 이름: 본금*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10나길 56, 이름: 신우**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10나길 79, 이름: 중국*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10나길 79, 이름: 고기* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10나길 80, 이름: 주향**** -> 찾은 이름: 주향 양꼬치
#   - 주소: 서울특별시 성동구 청계천로10다길 19, 이름: 하* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10다길 24, 이름: 누가** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10다길 61, 이름: 마천********* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로12가길 51, 이름: 한결** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 금호산2길 21-1, 이름: 앂.************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 독서당로62길 22-11, 이름: 얌이** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로14길 28-15, 이름: 플디********** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로14길 30-11, 이름: 포어** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로21가길 3-1, 이름: 옥이* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로8길 15, 이름: 샐러**************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수이로7가길 21-17, 이름: 하람** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 성수일로4가길 10-14, 이름: 스켓****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 왕십리로31가길 10-2, 이름: 브렛******** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10가길 10-9, 이름: 마장********* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로12가길 40-3, 이름: 신영**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로12가길 6-24, 이름: 금복** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로12가길 75-3, 이름: 브이**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 고산자로6가길 21, 이름: 레* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 아차산로 153, 이름: 성수** -> 찾은 이름: 성수정찬
#   - 주소: 서울특별시 성동구 왕십리로16가길 10-30, 이름: 뻬따******* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10가길 10-13, 이름: 제일*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10가길 64-12, 이름: 청계** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10가길 64-12, 이름: 청계** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10다길 34-14, 이름: 태민** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 363-1 (하왕십리동), 이름: 꼬치*** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 용답길 157-31, 이름: 장성** -> 찾은 이름: 장성식당
#   - 주소: 서울특별시 성동구 아차산로13길 37, 이름: 쉭앤**** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 청계천로10가길 38, 이름: 고박****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 고산자로 284, 이름: 그린* -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 마장로44길 8-18, 이름: 카페****** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 고산자로8가길 12, 이름: 소예***** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 성수일로12길 34, 이름: 오니****** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 광나루로 296, 이름: 퓨엘** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 금호로 82-1, 이름: 더 **** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 마장로 137, 이름: 언코***** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 금호로11길 3, 이름: 금호*** -> 찾은 이름: 금호돼지집
#   - 주소: 서울특별시 성동구 무학봉길 53-1, 이름: 비비*** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 용답29길 28 , 이름: 럼프************** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 아차산로17길 57, 이름: 컴포********** -> 찾은 이름: Not Found
#   - 주소: 서울특별시 성동구 마장로 137, 이름: 아이********** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 독서당로 223, 이름: 어반** -> 찾은 이름: 어반스푼
#   - 주소: 서울특별시 성동구 마장로35길 76, 이름: 한성** -> 찾은 이름: Not Found
#   - 주소: 서울 성동구 왕십리로 410, 이름: 국수** -> 찾은 이름: 국수일가
#   - 주소: 서울특별시 성동구 매봉길 50, 이름: 아이****** -> 찾은 이름: Not Found
#
# 작업 완료! 결과가 'c:\Users\hyunj\Bigcontest\BIgcontest_Data\big_data_with_kakao_names_v3.csv' 파일로 저장되었습니다.
#
# 결과 미리보기:
#    MCT_BSE_AR MCT_NM FOUND_MCT_NM
# 0  서울 성동구 마장동   성우**    Not Found
# 1  서울 성동구 마장동   대보**    Not Found
# 2  서울 성동구 마장동   대용**    Not Found
# 3  서울 성동구 마장동   통일**    Not Found
# 4  서울 성동구 마장동   한울**    Not Found

# %%
import sys
import subprocess
import warnings

# ==============================================================================
# -1. 필수 라이브러리 설치 (실행 환경 초기화 대비)
# ==============================================================================
try:
    print("--- 필수 라이브러리 설치 시작 ---")
    python_executable = sys.executable
    subprocess.check_call([
        python_executable, "-m", "pip", "install",
        "pandas", "requests", "python-dotenv", "tqdm",
        "selenium", "webdriver-manager"
    ])
    print("✅ 라이브러리 설치 완료!")
except Exception as e:
    print(f"❌ 오류: 라이브러리 설치에 실패했습니다: {e}")
    sys.exit(1)

# Selenium 관련 경고 숨기기 (기능 영향 없음)
warnings.filterwarnings("ignore", category=UserWarning, module="selenium")


import pandas as pd
import time
import re
import os
from dotenv import load_dotenv
from tqdm import tqdm

# Selenium 관련 라이브러리
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException

def find_name_with_selenium(driver, address, masked_name):
    """
    셀레니움을 이용해 카카오맵에서 검색하고, 조건에 맞는 가게 이름을 찾아 반환합니다.
    """
    try:
        prefix = masked_name.split('*')[0]
        original_len = len(masked_name)
        
        # 주소 마지막 부분 + 가게 이름 앞부분으로 검색어 생성
        last_word_of_address = address.split()[-1] if address.split() else ''
        search_keyword = f"{last_word_of_address} {prefix}"

        # 1. 검색창에 키워드 입력 및 검색
        search_box = driver.find_element(By.ID, "search.keyword.query")
        search_box.clear() # 이전 검색어 지우기
        search_box.send_keys(search_keyword)
        search_box.send_keys(Keys.RETURN)
        time.sleep(2) # 검색 결과 로딩 대기

        # 2. '장소' 탭 클릭 (필요 시)
        try:
            driver.find_element(By.ID, "info.search.place.more").click()
            time.sleep(1)
        except NoSuchElementException:
            pass # 장소 탭이 이미 선택되어 있거나, 버튼이 없는 경우

        # 3. 검색 결과 목록에서 이름 스크래핑
        places = driver.find_elements(By.CSS_SELECTOR, "#info\\.search\\.place\\.list > li")
        
        for place in places:
            try:
                place_name = place.find_element(By.CSS_SELECTOR, "a.link_name").text
                # 조건: 앞부분 일치 & 전체 글자 수 일치
                if place_name.startswith(prefix) and len(place_name) == original_len:
                    return place_name # 조건에 맞는 첫 번째 결과를 반환
            except NoSuchElementException:
                continue # 광고 등 다른 li는 건너뛰기

        return "Not Found" # 조건에 맞는 가게를 못 찾음

    except Exception as e:
        # print(f"  - Selenium 검색 중 오류 발생: {e}")
        return "Selenium Error"

# --- 메인 코드 실행 부분 ---

# 1. 파일 경로 설정
load_dotenv()

# 만약 .env 파일 등을 사용하지 않는 경우, 아래처럼 직접 파일명을 입력하세요.
input_filename = DATA_DIR/'big_data_with_kakao_names_v3.csv'
output_filename = DATA_DIR/'big_data_with_selenium_results.csv'


# 2. Selenium WebDriver 설정
print("Selenium WebDriver를 설정합니다...")
options = webdriver.ChromeOptions()
# options.add_argument("--headless") # 브라우저 창 숨기기
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)
print("WebDriver 설정 완료.")

try:
    # 3. 카카오맵 접속
    driver.get("https://map.kakao.com/")
    driver.implicitly_wait(5)

    # 4. 데이터 불러오기 및 'Not Found' 필터링
    df = pd.read_csv(input_filename, encoding='utf-8-sig')
    not_found_df = df[df['FOUND_MCT_NM'] == 'Not Found'].copy()

    if not_found_df.empty:
        print("'Not Found'인 항목이 없습니다. 작업을 종료합니다.")
    else:
        print(f"총 {len(df)}개 데이터 중 'Not Found'인 {len(not_found_df)}개에 대해 Selenium 검색을 시작합니다.")
        
        # 5. 'Not Found' 항목에 대해 Selenium 검색 실행
        for index, row in tqdm(not_found_df.iterrows(), total=not_found_df.shape[0]):
            original_address = row['MCT_BSE_AR']
            masked_name = row['MCT_NM']
            
            if pd.isna(original_address) or pd.isna(masked_name):
                continue
            
            cleaned_address = re.sub(r'\s+[\d-]+$', '', str(original_address)).strip()
            
            # 셀레니움 함수 호출
            found_name = find_name_with_selenium(driver, cleaned_address, masked_name)
            
            # 원본 DataFrame에 결과 업데이트
            df.loc[index, 'FOUND_MCT_NM'] = found_name
        
        # 6. 최종 결과 저장
        df.to_csv(output_filename, index=False, encoding='utf-8-sig')

        print(f"\n작업 완료! 최종 결과가 '{output_filename}' 파일로 저장되었습니다.")
        
        final_found_count = df[~df['FOUND_MCT_NM'].isin(['Not Found', 'Selenium Error'])].shape[0]
        newly_found_count = final_found_count - (len(df) - len(not_found_df))
        
        print(f" - 이번 Selenium 작업을 통해 {newly_found_count}개의 이름을 추가로 찾았습니다.")
        print(f" - 최종적으로 찾은 이름 수: {final_found_count} / {len(df)}")

except FileNotFoundError:
    print(f"오류: 이전 결과 파일인 '{input_filename}'을 찾을 수 없습니다.")
except Exception as e:
    print(f"메인 코드 실행 중 오류가 발생했습니다: {e}")
finally:
    # 7. 드라이버 종료
    print("브라우저를 닫습니다.")
    driver.quit()
